# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"E:\AI & ML\market_basket_analysis\Market_Basket_Optimisation.csv")

# %%
transactions=[]
for i in range(0,len(dataset)):
    transactions.append([str(dataset.values[i,j]) for j in range(0,20)])
dataset.head(30)
# Out:
#                shrimp          almonds        avocado    vegetables mix  \
# 0             burgers        meatballs           eggs               NaN
# 1             chutney              NaN            NaN               NaN
# 2              turkey          avocado            NaN               NaN
# 3       mineral water             milk     energy bar  whole wheat rice
# 4      low fat yogurt              NaN            NaN               NaN
# 5   whole wheat pasta     french fries            NaN               NaN
# 6                soup      light cream        shallot               NaN
# 7   frozen vegetables        spaghetti      green tea               NaN
# 8        french fries              NaN            NaN               NaN
# 9                eggs         pet food            NaN               NaN
# 10            cookies              NaN            NaN               NaN
# 11             turkey          burgers  mineral water              eggs
# 12          spaghetti        champagne        cookies               NaN
# 13      mineral water           salmon            NaN               NaN
# 14      mineral water              NaN            NaN               NaN
# 15             shrimp        chocolate        chicken             honey
# 16             turkey             eggs            NaN               NaN
# 17             turkey       fresh tuna       tomatoes         spaghetti
# 18          meatballs             milk          honey      french fries
# 19           red wine           shrimp          pasta            pepper
# 20               rice  sparkling water            NaN               NaN
# 21          spaghetti    mineral water            ham        body spray
# 22            burgers    grated cheese         shrimp             pasta
# 23               eggs              NaN            NaN               NaN
# 24    parmesan cheese        spaghetti           soup           avocado
# 25        ground beef        spaghetti  mineral water              milk
# 26    sparkling water              NaN            NaN               NaN
# 27      mineral water             eggs        chicken         chocolate
# 28  frozen vegetables        spaghetti           yams     mineral water
# 29      herb & pepper     tomato sauce    light cream         magazines
#
#      green grapes whole weat flour            yams   cottage cheese  \
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3       green tea              NaN             NaN              NaN
# 4             NaN              NaN             NaN              NaN
# 5             NaN              NaN             NaN              NaN
# 6             NaN              NaN             NaN              NaN
# 7             NaN              NaN             NaN              NaN
# 8             NaN              NaN             NaN              NaN
# 9             NaN              NaN             NaN              NaN
# 10            NaN              NaN             NaN              NaN
# 11    cooking oil              NaN             NaN              NaN
# 12            NaN              NaN             NaN              NaN
# 13            NaN              NaN             NaN              NaN
# 14            NaN              NaN             NaN              NaN
# 15            oil      cooking oil  low fat yogurt              NaN
# 16            NaN              NaN             NaN              NaN
# 17  mineral water        black tea          salmon             eggs
# 18    protein bar              NaN             NaN              NaN
# 19           eggs        chocolate         shampoo              NaN
# 20            NaN              NaN             NaN              NaN
# 21       pancakes        green tea             NaN              NaN
# 22        avocado            honey      white wine       toothpaste
# 23            NaN              NaN             NaN              NaN
# 24           milk      fresh bread             NaN              NaN
# 25     energy bar        black tea          salmon  frozen smoothie
# 26            NaN              NaN             NaN              NaN
# 27   french fries              NaN             NaN              NaN
# 28            NaN              NaN             NaN              NaN
# 29            NaN              NaN             NaN              NaN
#
#    energy drink          tomato juice low fat yogurt green tea honey salad  \
# 0           NaN                   NaN            NaN       NaN   NaN   NaN
# 1           NaN                   NaN            NaN       NaN   NaN   NaN
# 2           NaN                   NaN            NaN       NaN   NaN   NaN
# 3           NaN                   NaN            NaN       NaN   NaN   NaN
# 4           NaN                   NaN            NaN       NaN   NaN   NaN
# 5           NaN                   NaN            NaN       NaN   NaN   NaN
# 6           NaN                   NaN            NaN       NaN   NaN   NaN
# 7           NaN                   NaN            NaN       NaN   NaN   NaN
# 8           NaN                   NaN            NaN       NaN   NaN   NaN
# 9           NaN                   NaN            NaN       NaN   NaN   NaN
# 10          NaN                   NaN            NaN       NaN   NaN   NaN
# 11          NaN                   NaN            NaN       NaN   NaN   NaN
# 12          NaN                   NaN            NaN       NaN   NaN   NaN
# 13          NaN                   NaN            NaN       NaN   NaN   NaN
# 14          NaN                   NaN            NaN       NaN   NaN   NaN
# 15          NaN                   NaN            NaN       NaN   NaN   NaN
# 16          NaN                   NaN            NaN       NaN   NaN   NaN
# 17      chicken  extra dark chocolate            NaN       NaN   NaN   NaN
# 18          NaN                   NaN            NaN       NaN   NaN   NaN
# 19          NaN                   NaN            NaN       NaN   NaN   NaN
# 20          NaN                   NaN            NaN       NaN   NaN   NaN
# 21          NaN                   NaN            NaN       NaN   NaN   NaN
# 22          NaN                   NaN            NaN       NaN   NaN   NaN
# 23          NaN                   NaN            NaN       NaN   NaN   NaN
# 24          NaN                   NaN            NaN       NaN   NaN   NaN
# 25     escalope                   NaN            NaN       NaN   NaN   NaN
# 26          NaN                   NaN            NaN       NaN   NaN   NaN
# 27          NaN                   NaN            NaN       NaN   NaN   NaN
# 28          NaN                   NaN            NaN       NaN   NaN   NaN
# 29          NaN                   NaN            NaN       NaN   NaN   NaN
#
#    mineral water salmon antioxydant juice frozen smoothie spinach  olive oil
# 0            NaN    NaN               NaN             NaN     NaN        NaN
# 1            NaN    NaN               NaN             NaN     NaN        NaN
# 2            NaN    NaN               NaN             NaN     NaN        NaN
# 3            NaN    NaN               NaN             NaN     NaN        NaN
# 4            NaN    NaN               NaN             NaN     NaN        NaN
# 5            NaN    NaN               NaN             NaN     NaN        NaN
# 6            NaN    NaN               NaN             NaN     NaN        NaN
# 7            NaN    NaN               NaN             NaN     NaN        NaN
# 8            NaN    NaN               NaN             NaN     NaN        NaN
# 9            NaN    NaN               NaN             NaN     NaN        NaN
# 10           NaN    NaN               NaN             NaN     NaN        NaN
# 11           NaN    NaN               NaN             NaN     NaN        NaN
# 12           NaN    NaN               NaN             NaN     NaN        NaN
# 13           NaN    NaN               NaN             NaN     NaN        NaN
# 14           NaN    NaN               NaN             NaN     NaN        NaN
# 15           NaN    NaN               NaN             NaN     NaN        NaN
# 16           NaN    NaN               NaN             NaN     NaN        NaN
# 17           NaN    NaN               NaN             NaN     NaN        NaN
# 18           NaN    NaN               NaN             NaN     NaN        NaN
# 19           NaN    NaN               NaN             NaN     NaN        NaN
# 20           NaN    NaN               NaN             NaN     NaN        NaN
# 21           NaN    NaN               NaN             NaN     NaN        NaN
# 22           NaN    NaN               NaN             NaN     NaN        NaN
# 23           NaN    NaN               NaN             NaN     NaN        NaN
# 24           NaN    NaN               NaN             NaN     NaN        NaN
# 25           NaN    NaN               NaN             NaN     NaN        NaN
# 26           NaN    NaN               NaN             NaN     NaN        NaN
# 27           NaN    NaN               NaN             NaN     NaN        NaN
# 28           NaN    NaN               NaN             NaN     NaN        NaN
# 29           NaN    NaN               NaN             NaN     NaN        NaN

# %%
transactions[:3]
transactions[:5]
# Out:
# [['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan']]

# %%
from apyori import apriori
rules=apriori(transactions,min_support=0.03,min_confidence=0.2,min_left=3,min_length=2)

# %%
results=list(rules)

# %%
lift=[]
association=[]
for i in range(0,len(results)):
    lift.append(results[:len(results)][i][2][0][3])
    association.append(list(results[:len(results)][i][0]))

# %%
rank = pd.DataFrame([association, lift]).transpose()
rank.columns = ['Association', 'Lift']

# %%
rank.sort_values('Lift', ascending=False).head(10)
# Out:
#                                 Association      Lift
# 68            [spaghetti, nan, ground beef]  2.290857
# 34                 [spaghetti, ground beef]  2.290857
# 67        [nan, ground beef, mineral water]  1.748266
# 32             [ground beef, mineral water]  1.748266
# 65  [frozen vegetables, nan, mineral water]  1.573133
# 27       [frozen vegetables, mineral water]  1.573133
# 70                   [milk, nan, spaghetti]  1.571569
# 41                        [milk, spaghetti]  1.571569
# 69               [milk, nan, mineral water]  1.554436
# 39                    [milk, mineral water]  1.554436

# %%
items = []
for i in range(0, len(transactions)):
    items.extend(transactions[i])

# %%
items = []
for i in range(0, len(transactions)):
    items.extend(transactions[i])

# %%
uniqueItems=list(set(items))
uniqueItems.remove('nan')

uniqueItems
# Out:
# ['chocolate bread',
#  'energy drink',
#  'toothpaste',
#  'honey',
#  'carrots',
#  'white wine',
#  'green beans',
#  'almonds',
#  'low fat yogurt',
#  'yogurt cake',
#  'frozen vegetables',
#  'red wine',
#  'extra dark chocolate',
#  'pasta',
#  'tomato sauce',
#  'green tea',
#  'salmon',
#  'mint green tea',
#  'whole wheat pasta',
#  'yams',
#  'salad',
#  'tea',
#  'soup',
#  'fromage blanc',
#  'bug spray',
#  'ham',
#  'soda',
#  'vegetables mix',
#  'eggs',
#  'cream',
#  'flax seed',
#  'energy bar',
#  'light cream',
#  'magazines',
#  'water spray',
#  'strawberries',
#  'ketchup',
#  'cauliflower',
#  'asparagus',
#  'muffins',
#  'chicken',
#  'ground beef',
#  'sparkling water',
#  'bacon',
#  'cake',
#  'pepper',
#  'clothes accessories',
#  'dessert wine',
#  'burgers',
#  'mineral water',
#  'escalope',
#  'olive oil',
#  'gums',
#  'parmesan cheese',
#  'mashed potato',
#  'spaghetti',
#  'pancakes',
#  'champagne',
#  'oil',
#  'fresh tuna',
#  'protein bar',
#  'chocolate',
#  'blueberries',
#  'cottage cheese',
#  'shrimp',
#  'zucchini',
#  'gluten free bar',
#  'pickles',
#  'brownies',
#  'salt',
#  'herb & pepper',
#  'frozen smoothie',
#  'oatmeal',
#  'whole weat flour',
#  'candy bars',
#  'nonfat milk',
#  'french wine',
#  'sandwich',
#  'light mayo',
#  'corn',
#  'babies food',
#  'mushroom cream sauce',
#  'grated cheese',
#  'burger sauce',
#  'eggplant',
#  'butter',
#  'black tea',
#  'cooking oil',
#  'milk',
#  'antioxydant juice',
#  'tomatoes',
#  'hand protein bar',
#  'strong cheese',
#  'melons',
#  'spinach',
#  'avocado',
#  'tomato juice',
#  'french fries',
#  'cider',
#  'chili',
#  'bramble',
#  'mint',
#  'shallot',
#  'hot dogs',
#  'barbecue sauce',
#  'cereals',
#  'napkins',
#  'turkey',
#  'whole wheat rice',
#  ' asparagus',
#  'pet food',
#  'rice',
#  'fresh bread',
#  'meatballs',
#  'body spray',
#  'cookies',
#  'chutney',
#  'shampoo',
#  'green grapes',
#  'mayonnaise']

# %%
pair=[]
for j in range(0,len(uniqueItems)):
    k=1;
while k<=len(uniqueItems):
    try:
        pair.append([uniqueItems[j],uniqueItems[j+k]])
    except IndexError:
        pass
    k=k+1
pair
# Out:
# []

# %%
score=[]
for i in pair:
    cond=[]
    for item in i:
        cond.append('("%s") in s'%item)
    code=('[s for s in transactions if '+' and '.join(cond)+ ']')
    score.append(len(eval(code))/7501)

# %%
ranking_ECLAT=pd.DataFrame([pair,score]).transpose()
ranking_ECLAT.columns=['Pair','Score']
ranking_ECLAT.sort_values('Score',ascending=False).head(10)
# Out:
# Empty DataFrame
# Columns: [Pair, Score]
# Index: []

# %%
trio=[]
for j in range(0,len(uniqueItems)):
    for k in range(j,len(uniqueItems)):
        for l in range(k,len(uniqueItems)):
            if(k!=j) and (j!=l) and (k!=l):
                try:
                    trio.append([uniqueItems[j],uniqueItems[j+k],uniqueItems[j+1]])
                except IndexError:
                    pass
trio[:5]
# Out:
# [['chocolate bread', 'energy drink', 'energy drink'],
#  ['chocolate bread', 'energy drink', 'energy drink'],
#  ['chocolate bread', 'energy drink', 'energy drink'],
#  ['chocolate bread', 'energy drink', 'energy drink'],
#  ['chocolate bread', 'energy drink', 'energy drink']]

# %%
score_trio=[]
for in trio:
    cond=[]
    for item in i:
        cond.append()
